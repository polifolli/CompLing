# %% [markdown]
# # Домашнее задание № 1

# %%
# !pip install pymystem3
# !pip install pymorphy2
# !pip install razdel
# !pip install gensim
# !pip install nltk
# !pip install rusenttokenize
# !pip install regex
# !pip install pymorphy3

# %% [markdown]
# ## Задание 1 (2 балла)

# %% [markdown]
# Найдите 1 любой способ сломать токенизацию на предложения функцией sentenize из библиотеки razdel. Придумайте (или найдите на каком-то корпусе) такое предложение (или несколько предложений), которое будет некорректно разобрано sentenize, но при этом будет грамматически корректным.

# %%
from razdel import sentenize

# %%
# ваш код
text = """Выхожу один я на дорогу;
Сквозь туман кремнистый путь блестит;
Ночь тиха. Пустыня внемлет богу,
И звезда с звездою говорит.
В небесах торжественно и чудно!
Спит земля в сиянье голубом...
Что же мне так больно и так трудно?
Жду ль чего? жалею ли о чем?"""

sents = list(sentenize(text))
for x in sents:
    print(x)
# Out:
# Substring(0, 24, 'Выхожу один я на дорогу;')
# Substring(25, 62, 'Сквозь туман кремнистый путь блестит;')
# Substring(63, 73, 'Ночь тиха.')
# Substring(74, 123, 'Пустыня внемлет богу,\nИ звезда с звездою говорит.')
# Substring(124, 155, 'В небесах торжественно и чудно!')
# Substring(156, 186, 'Спит земля в сиянье голубом...')
# Substring(187, 222, 'Что же мне так больно и так трудно?')
# Substring(223, 251, 'Жду ль чего? жалею ли о чем?')

# %% [markdown]
# Токенайзер не разбил на предложения последнюю строку. Очевидно почему так произошло - Лермонтов не использовал заглавную букву в начале предложения ради сохранения ритмического элемента стиха

# %% [markdown]
# ## 2. Токенизация Mystem vs razdel.tokenize (2 балла)
#
#
# Токенизируйте текст с помощью razdel и с помощью Mystem. Найдите различия в токенизациях. Что по вашему работает лучше на приведенном тексте?

# %%
from pymystem3 import Mystem
from razdel import tokenize as razdel_tokenize

# %%
text = """
Вторым и третьим открытыми белыми карликами стали Сириус B и Процион B. В 1844 году директор Кёнигсбергской обсерватории Фридрих Бессель, анализируя данные наблюдений, которые велись с 1755 года, обнаружил, что Сириус, ярчайшая звезда земного неба, и Процион периодически, хотя и весьма слабо, отклоняются от прямолинейной траектории движения по небесной сфере[5]. Бессель пришёл к выводу, что у каждой из них должен быть близкий спутник. Сообщение было встречено скептически, поскольку слабый спутник оставался ненаблюдаемым, а его масса должна была быть достаточно велика — сравнимой с массой Сириуса и Проциона, соответственно.

В январе 1862 года Элвин Грэхэм Кларк, юстируя 18-дюймовый рефрактор, самый большой на то время телескоп в мире (Dearborn Telescope), впоследствии поставленный семейной фирмой Кларков в обсерваторию Чикагского университета, обнаружил в непосредственной близости от Сириуса тусклую звёздочку. Это был спутник Сириуса, Сириус B, предсказанный Бесселем[6]. А в 1896 году американский астроном Д. М. Шеберле открыл Процион B, подтвердив тем самым и второе предсказание Бесселя.

В 1915 году американский астроном Уолтер Сидней Адамс измерил спектр Сириуса B. Из измерений следовало, что его температура не ниже, чем у Сириуса A (по современным данным, температура поверхности Сириуса B составляет 25 000 K, а Сириуса A — 10 000 К), что, с учётом его в 10 000 раз меньшей, чем у Сириуса A, светимости указывает на очень малый радиус и, соответственно, высокую плотность — 106 г/см3 (плотность Сириуса ~0,25 г/см3, плотность Солнца ~1,4 г/см3).
"""

# %%
razdel_token_result = [token.text for token in list(razdel_tokenize(text))]
razdel_token_result
# Out:
# ['Вторым',
#  'и',
#  'третьим',
#  'открытыми',
#  'белыми',
#  'карликами',
#  'стали',
#  'Сириус',
#  'B',
#  'и',
#  'Процион',
#  'B',
#  '.',
#  'В',
#  '1844',
#  'году',
#  'директор',
#  'Кёнигсбергской',
#  'обсерватории',
#  'Фридрих',
#  'Бессель',
#  ',',
#  'анализируя',
#  'данные',
#  'наблюдений',
#  ',',
#  'которые',
#  'велись',
#  'с',
#  '1755',
#  'года',
#  ',',
#  'обнаружил',
#  ',',
#  'что',
#  'Сириус',
#  ',',
#  'ярчайшая',
#  'звезда',
#  'земного',
#  'неба',
#  ',',
#  'и',
#  'Процион',
#  'периодически',
#  ',',
#  'хотя',
#  'и',
#  'весьма',
#  'слабо',
#  ',',
#  'отклоняются',
#  'от',
#  'прямолинейной',
#  'траектории',
#  'движения',
#  'по',
#  'небесной',
#  'сфере',
#  '[',
#  '5',
#  ']',
#  '.',
#  'Бессель',
#  'пришёл',
#  'к',
#  'выводу',
#  ',',
#  'что',
#  'у',
#  'каждой',
#  'из',
#  'них',
#  'должен',
#  'быть',
#  'близкий',
#  'спутник',
#  '.',
#  'Сообщение',
#  'было',
#  'встречено',
#  'скептически',
#  ',',
#  'поскольку',
#  'слабый',
#  'спутник',
#  'оставался',
#  'ненаблюдаемым',
#  ',',
#  'а',
#  'его',
#  'масса',
#  'должна',
#  'была',
#  'быть',
#  'достаточно',
#  'велика',
#  '—',
#  'сравнимой',
#  'с',
#  'массой',
#  'Сириуса',
#  'и',
#  'Проциона',
#  ',',
#  'соответственно',
#  '.',
#  'В',
#  'январе',
#  '1862',
#  'года',
#  'Элвин',
#  'Грэхэм',
#  'Кларк',
#  ',',
#  'юстируя',
#  '18-дюймовый',
#  'рефрактор',
#  ',',
#  'самый',
#  'большой',
#  'на',
#  'то',
#  'время',
#  'телескоп',
#  'в',
#  'мире',
#  '(',
#  'Dearborn',
#  'Telescope',
#  ')',
#  ',',
#  'впоследствии',
#  'поставленный',
#  'семейной',
#  'фирмой',
#  'Кларков',
#  'в',
#  'обсерваторию',
#  'Чикагского',
#  'университета',
#  ',',
#  'обнаружил',
#  'в',
#  'непосредственной',
#  'близости',
#  'от',
#  'Сириуса',
#  'тусклую',
#  'звёздочку',
#  '.',
#  'Это',
#  'был',
#  'спутник',
#  'Сириуса',
#  ',',
#  'Сириус',
#  'B',
#  ',',
#  'предсказанный',
#  'Бесселем',
#  '[',
#  '6',
#  ']',
#  '.',
#  'А',
#  'в',
#  '1896',
#  'году',
#  'американский',
#  'астроном',
#  'Д',
#  '.',
#  'М',
#  '.',
#  'Шеберле',
#  'открыл',
#  'Процион',
#  'B',
#  ',',
#  'подтвердив',
#  'тем',
#  'самым',
#  'и',
#  'второе',
#  'предсказание',
#  'Бесселя',
#  '.',
#  'В',
#  '1915',
#  'году',
#  'американский',
#  'астроном',
#  'Уолтер',
#  'Сидней',
#  'Адамс',
#  'измерил',
#  'спектр',
#  'Сириуса',
#  'B',
#  '.',
#  'Из',
#  'измерений',
#  'следовало',
#  ',',
#  'что',
#  'его',
#  'температура',
#  'не',
#  'ниже',
#  ',',
#  'чем',
#  'у',
#  'Сириуса',
#  'A',
#  '(',
#  'по',
#  'современным',
#  'данным',
#  ',',
#  'температура',
#  'поверхности',
#  'Сириуса',
#  'B',
#  'составляет',
#  '25',
#  '000',
#  'K',
#  ',',
#  'а',
#  'Сириуса',
#  'A',
#  '—',
#  '10',
#  '000',
#  'К',
#  ')',
#  ',',
#  'что',
#  ',',
#  'с',
#  'учётом',
#  'его',
#  'в',
#  '10',
#  '000',
#  'раз',
#  'меньшей',
#  ',',
#  'чем',
#  'у',
#  'Сириуса',
#  'A',
#  ',',
#  'светимости',
#  'указывает',
#  'на',
#  'очень',
#  'малый',
#  'радиус',
#  'и',
#  ',',
#  'соответственно',
#  ',',
#  'высокую',
#  'плотность',
#  '—',
#  '106',
#  'г',
#  '/',
#  'см',
#  '3',
#  '(',
#  'плотность',
#  'Сириуса',
#  '~',
#  '0,25',
#  'г',
#  '/',
#  'см',
#  '3',
#  ',',
#  'плотность',
#  'Солнца',
#  '~',
#  '1,4',
#  'г',
#  '/',
#  'см',
#  '3',
#  ')',
#  '.']

# %%
mystem = Mystem()
words_analized = mystem.analyze(text)

# %%
mystem_token_result = []
for x in words_analized:
    if x['text'] != ' ' and x['text'] != '\n':
        mystem_token_result.append(x['text'])

mystem_token_result
# Out:
# ['Вторым',
#  'и',
#  'третьим',
#  'открытыми',
#  'белыми',
#  'карликами',
#  'стали',
#  'Сириус',
#  'B',
#  'и',
#  'Процион',
#  'B',
#  '. ',
#  'В',
#  '1844',
#  'году',
#  'директор',
#  'Кёнигсбергской',
#  'обсерватории',
#  'Фридрих',
#  'Бессель',
#  ', ',
#  'анализируя',
#  'данные',
#  'наблюдений',
#  ', ',
#  'которые',
#  'велись',
#  'с',
#  '1755',
#  'года',
#  ', ',
#  'обнаружил',
#  ', ',
#  'что',
#  'Сириус',
#  ', ',
#  'ярчайшая',
#  'звезда',
#  'земного',
#  'неба',
#  ', ',
#  'и',
#  'Процион',
#  'периодически',
#  ', ',
#  'хотя',
#  'и',
#  'весьма',
#  'слабо',
#  ', ',
#  'отклоняются',
#  'от',
#  'прямолинейной',
#  'траектории',
#  'движения',
#  'по',
#  'небесной',
#  'сфере',
#  '[',
#  '5',
#  ']',
#  '. ',
#  'Бессель',
#  'пришёл',
#  'к',
#  'выводу',
#  ', ',
#  'что',
#  'у',
#  'каждой',
#  'из',
#  'них',
#  'должен',
#  'быть',
#  'близкий',
#  'спутник',
#  '. ',
#  'Сообщение',
#  'было',
#  'встречено',
#  'скептически',
#  ', ',
#  'поскольку',
#  'слабый',
#  'спутник',
#  'оставался',
#  'ненаблюдаемым',
#  ', ',
#  'а',
#  'его',
#  'масса',
#  'должна',
#  'была',
#  'быть',
#  'достаточно',
#  'велика',
#  ' — ',
#  'сравнимой',
#  'с',
#  'массой',
#  'Сириуса',
#  'и',
#  'Проциона',
#  ', ',
#  'соответственно',
#  '.',
#  'В',
#  'январе',
#  '1862',
#  'года',
#  'Элвин',
#  'Грэхэм',
#  'Кларк',
#  ', ',
#  'юстируя',
#  '18',
#  '-',
#  'дюймовый',
#  'рефрактор',
#  ', ',
#  'самый',
#  'большой',
#  'на',
#  'то',
#  'время',
#  'телескоп',
#  'в',
#  'мире',
#  ' (',
#  'Dearborn',
#  'Telescope',
#  '), ',
#  'впоследствии',
#  'поставленный',
#  'семейной',
#  'фирмой',
#  'Кларков',
#  'в',
#  'обсерваторию',
#  'Чикагского',
#  'университета',
#  ', ',
#  'обнаружил',
#  'в',
#  'непосредственной',
#  'близости',
#  'от',
#  'Сириуса',
#  'тусклую',
#  'звёздочку',
#  '. ',
#  'Это',
#  'был',
#  'спутник',
#  'Сириуса',
#  ', ',
#  'Сириус',
#  'B',
#  ', ',
#  'предсказанный',
#  'Бесселем',
#  '[',
#  '6',
#  ']',
#  '. ',
#  'А',
#  'в',
#  '1896',
#  'году',
#  'американский',
#  'астроном',
#  'Д',
#  '. ',
#  'М',
#  '. ',
#  'Шеберле',
#  'открыл',
#  'Процион',
#  'B',
#  ', ',
#  'подтвердив',
#  'тем',
#  'самым',
#  'и',
#  'второе',
#  'предсказание',
#  'Бесселя',
#  '.',
#  'В',
#  '1915',
#  'году',
#  'американский',
#  'астроном',
#  'Уолтер',
#  'Сидней',
#  'Адамс',
#  'измерил',
#  'спектр',
#  'Сириуса',
#  'B',
#  '. ',
#  'Из',
#  'измерений',
#  'следовало',
#  ', ',
#  'что',
#  'его',
#  'температура',
#  'не',
#  'ниже',
#  ', ',
#  'чем',
#  'у',
#  'Сириуса',
#  'A',
#  ' (',
#  'по',
#  'современным',
#  'данным',
#  ', ',
#  'температура',
#  'поверхности',
#  'Сириуса',
#  'B',
#  'составляет',
#  '25',
#  '000',
#  'K',
#  ', ',
#  'а',
#  'Сириуса',
#  'A',
#  ' — ',
#  '10',
#  '000',
#  'К',
#  '), ',
#  'что',
#  ', ',
#  'с',
#  'учётом',
#  'его',
#  'в',
#  '10',
#  '000',
#  'раз',
#  'меньшей',
#  ', ',
#  'чем',
#  'у',
#  'Сириуса',
#  'A',
#  ', ',
#  'светимости',
#  'указывает',
#  'на',
#  'очень',
#  'малый',
#  'радиус',
#  'и',
#  ', ',
#  'соответственно',
#  ', ',
#  'высокую',
#  'плотность',
#  ' — ',
#  '106',
#  'г',
#  '/',
#  'см3',
#  ' (',
#  'плотность',
#  'Сириуса',
#  ' ~',
#  '0',
#  ',',
#  '25',
#  'г',
#  '/',
#  'см3',
#  ', ',
#  'плотность',
#  'Солнца',
#  ' ~',
#  '1',
#  ',',
#  '4',
#  'г',
#  '/',
#  'см3',
#  ')',
#  '.']

# %% [markdown]
# ## Вывод
# В целом оба токенизатора сработали хорошо.
#
# Токенизатор из razdel лучше распознал десятичные дроби (типа 0,25)
#
# Токенизатор Mystem лучше распознал см3 (не стал отделять куб)

# %% [markdown]
# ## 3. Лемматизация Mystem vs Pymorphy (2 балла)

# %%
from pymorphy3 import MorphAnalyzer

# %%
morph = MorphAnalyzer()

# %% [markdown]
# Лемматизируйте текст с помощью mystem и pymorphy. Найдите различия в лемматизации. Что по вашему работает лучше на приведенном тексте?

# %% [markdown]
# Важно: для пайморфи используйте токенизацию из mystem, чтобы исключить влияние токенизации на результат. Анализируйте только значимые различия, а не технические особенности (не сравнивайте скорость работы и удобность интерфейса).

# %%
mystem_lemms_result = [parse['analysis'][0]['lex'] for parse in words_analized if parse.get('analysis')]
# mystem_lemms_result
for lemma in mystem_lemms_result:
    print(lemma)
# Out:
# второй
# и
# третий
# открытый
# белый
# карлик
# становиться
# сириус
# и
# процион
# в
# год
# директор
# кенигсбергский
# обсерватория
# фридрих
# бессель
# анализировать
# данные
# наблюдение
# который
# вестись
# с
# год
# обнаруживать
# что
# сириус
# яркий
# звезда
# земной
# небо
# и
# процион
# периодически
# хотя
# и
# весьма
# слабо
# отклоняться
# от
# прямолинейный
# траектория
# движение
# по
# небесный
# сфера
# бессель
# приходить
# к
# вывод
# что
# у
# каждый
# из
# они
# должный
# быть
# близкий
# спутник
# сообщение
# быть
# встречать
# скептически
# поскольку
# слабый
# спутник
# оставаться
# ненаблюдаемый
# а
# его
# масса
# должный
# быть
# быть
# достаточно
# большой
# сравнимый
# с
# масса
# сириус
# и
# процион
# соответственно
# в
# январь
# год
# элвин
# грэхэм
# кларк
# юстировать
# дюймовый
# рефрактор
# самый
# большой
# на
# то
# время
# телескоп
# в
# мир
# впоследствии
# поставлять
# семейный
# фирма
# кларк
# в
# обсерватория
# чикагский
# университет
# обнаруживать
# в
# непосредственный
# близость
# от
# сириус
# тусклый
# звездочка
# это
# быть
# спутник
# сириус
# сириус
# предсказывать
# бессель
# а
# в
# год
# американский
# астроном
# д
# м
# шеберль
# открывать
# процион
# подтвердить
# то
# самый
# и
# второй
# предсказание
# бессель
# в
# год
# американский
# астроном
# уолтер
# сидней
# адамс
# измерять
# спектр
# сириус
# из
# измерение
# следовать
# что
# его
# температура
# не
# низкий
# чем
# у
# сириус
# по
# современный
# данные
# температура
# поверхность
# сириус
# составлять
# а
# сириус
# к
# что
# с
# учет
# он
# в
# раз
# меньший
# чем
# у
# сириус
# светимость
# указывать
# на
# очень
# малый
# радиус
# и
# соответственно
# высокий
# плотность
# г
# плотность
# сириус
# г
# плотность
# солнце
# г

# %%
words_analized_2 = [morph.parse(token) for token in mystem_token_result]

# %%
import string

# %%
string.punctuation += '«»—…“”'

# %%
pymorphy_lemms_result = []
for word in words_analized_2:
    if str(word[0].word).strip() not in string.punctuation:
        pymorphy_lemms_result.append(word[0].normal_form)
        # print(word[0].normal_form)
pymorphy_lemms_result
# Out:
# второй
# и
# третий
# открытый
# белый
# карлик
# стать
# сириус
# b
# и
# процион
# b
# в
# 1844
# год
# директор
# кёнигсбергский
# обсерватория
# фридрих
# бессель
# анализировать
# дать
# наблюдение
# который
# вестись
# с
# 1755
# год
# обнаружить
# что
# сириус
# яркий
# звезда
# земной
# небо
# и
# процион
# периодически
# хотя
# и
# весьма
# слабо
# отклоняться
# от
# прямолинейный
# траектория
# движение
# по
# небесный
# сфера
# 5
# бессель
# прийти
# к
# вывод
# что
# у
# каждый
# из
# они
# должный
# быть
# близкий
# спутник
# сообщение
# быть
# встретить
# скептически
# поскольку
# слабый
# спутник
# оставаться
# ненаблюдаемый
# а
# он
# масса
# должный
# быть
# быть
# достаточно
# большой
# сравнимый
# с
# масса
# сириус
# и
# процион
# соответственно
# в
# январь
# 1862
# год
# элвин
# грэхэма
# кларк
# юстировать
# 18
# дюймовый
# рефрактор
# самый
# большой
# на
# то
# время
# телескоп
# в
# мир
# dearborn
# telescope
# ),
# впоследствии
# поставить
# семейный
# фирма
# кларк
# в
# обсерватория
# чикагский
# университет
# обнаружить
# в
# непосредственный
# близость
# от
# сириус
# тусклый
# звёздочка
# это
# быть
# спутник
# сириус
# сириус
# b
# предсказать
# бессель
# 6
# а
# в
# 1896
# год
# американский
# астроном
# далее
# м
# шеберл
# открыть
# процион
# b
# подтвердить
# тем
# самый
# и
# второе
# предсказание
# бессель
# в
# 1915
# год
# американский
# астроном
# уолтер
# сидней
# адамс
# измерить
# спектр
# сириус
# b
# из
# измерение
# следовать
# что
# он
# температура
# не
# ниже
# чем
# у
# сириус
# a
# по
# современный
# данные
# температура
# поверхность
# сириус
# b
# составлять
# 25
# 000
# k
# а
# сириус
# a
# 10
# 000
# к
# ),
# что
# с
# учёт
# он
# в
# 10
# 000
# раз
# малый
# чем
# у
# сириус
# a
# светимость
# указывать
# на
# очень
# малый
# радиус
# и
# соответственно
# высокий
# плотность
# 106
# г
# см3
# плотность
# сириус
# 0
# 25
# г
# см3
# плотность
# солнце
# 1
# 4
# г
# см3

# %% [markdown]
# В Mystem убираются сразу числа и слова-сокращения типа см3.

# %% [markdown]
# ## 4. Лемматизация в SpaCy (2 балла)
#
# С помощью Spacy (модель для русского языка) лемматизируйте тот же текст. Проверьте есть ли различия с Mystem и Pymoprhy.

# %%
# !pip install spacy
# !python -m spacy download ru_core_news_sm

# %%
import spacy
nlp = spacy.load("ru_core_news_sm")

# %%
doc = nlp(text)
for sent in doc.sents: # достаем предложения
    for token in sent: # достаем токены
        if token.lemma_ not in string.punctuation:
            print(token.lemma_,)
    print()
# Out:
# второй
# и
# третий
# открытый
# белый
# карлик
# стать
# сириус
# b
# и
# процион
# b.
# в
# 1844
# год
# директор
# кёнигсбергский
# обсерватория
# фридрих
# бессель
# анализировать
# данные
# наблюдение
# которые
# вестись
# с
# 1755
# год
# обнаружить
# что
# сириус
# яркий
# звезда
# земной
# небо
# и
# процион
# периодически
# хотя
# и
# весьма
# слабо
# отклоняться
# от
# прямолинейный
# траектория
# движение
# по
# небесный
# сфере[5
#
# бессель
# прийти
# к
# вывод
# что
# у
# каждый
# из
# них
# должный
# быть
# близкий
# спутник
#
# сообщение
# было
# встретить
# скептически
# поскольку
# слабый
# спутник
# оставаться
# ненаблюдаемый
# а
# он
# масса
# должный
# быть
# быть
# достаточно
# большой
# сравнимый
# с
# масса
# сириус
# и
# проциона
# соответственно
#
#
#
#
# в
# январь
# 1862
# год
# элвин
# грэхэм
# кларк
# юстировать
# 18-дюймовый
# рефрактор
# самый
# большой
# на
# тот
# время
# телескоп
# в
# мир
# dearborn
# telescope
# впоследствии
# поставить
# семейный
# фирма
# кларков
# в
# обсерватория
# чикагского
# университет
# обнаружить
# в
# непосредственный
# близость
# от
# сириус
# тусклый
# звёздочка
#
# это
# быть
# спутник
# сириус
# сириус
# b
# предсказанный
# бесселем[6
#
# а
# в
# 1896
# год
# американский
# астроном
# д.
# м.
# шеберле
# открыть
# процион
# b
# подтвердить
# тем
# самым
# и
# второй
# предсказание
# бесселя
#
#
#
#
# в
# 1915
# год
# американский
# астроном
# уолтер
# сидней
# адамс
# измерить
# спектр
# сириус
# b.
# Из
# измерение
# следовать
# что
# он
# температура
# не
# низкий
# чем
# у
# сириус
# a
# по
# современный
# данным
# температура
# поверхность
# сириус
# b
# составлять
# 25
# 000
# k
# а
# сириуса
# a
# 10
# 000
# к
# что
# с
# учёт
# его
# в
# 10
# 000
# раз
# малый
# чем
# у
# сириус
# a
# светимость
# указывать
# на
# очень
# малый
# радиус
# и
# соответственно
# высокий
# плотность
# 106
# г
# см3
# плотность
# сириус
# ~0,25
# г
# см3
# плотность
# солнце
# ~1,4
# г
# см3

# %% [markdown]
# ## Замеченные различия
# 1. ![image.png](attachment:image.png)
#
# *Это был спутник Сириуса, Сириус B, **предсказанный** Бесселем*
#
# 2. ![image-2.png](attachment:image-2.png)
#
# Фамилия Шеберле
#
# 3. ![image-3.png](attachment:image-3.png)
#
# По-разному работают с цифрами

# %% [markdown]
# ## 5*. Дизамбигуация в Mystem (2 балла)

# %% [markdown]
# *необязательное задание на 10 баллов

# %% [markdown]
# Одна из фичей майстема - контекстная дизамбигуация (т.е. определение правильного разбора в зависимости от контекста).

# %% [markdown]
# Запустите mystem на очищенном тексте с дизамбигуацией и без и проверьте есть ли какие-то различия.

# %%
# ваш код
